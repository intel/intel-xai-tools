# %% [markdown]
# # Explaining zero shot learning
#
#
# see [Explaining transformer models using SHAP](https://github.com/PacktPublishing/Applied-Machine-Learning-Explainability-Techniques/blob/main/Chapter07/Explaining_Transformers.ipynb)

# %%
import warnings
warnings.filterwarnings('ignore')

# add zero_shot_learning.pkz to path which includes a shap entry_point. See zero_shot_learning.yaml
# to create the zero_shot_learning.pkz run 'explainer export zero_shot_learning'
from explainer.explainers import lm_zeroshot_explainer

import transformers
print(f"Hugging Face transformer version used: {transformers.__version__}")
from transformers import AutoModelForSequenceClassification, AutoTokenizer, ZeroShotClassificationPipeline
from typing import Union, List
# Out:
# Hugging Face transformer version used: 4.20.1

# %%
# Loading the hugging face model and tokenizer
model = AutoModelForSequenceClassification.from_pretrained("valhalla/distilbart-mnli-12-3")
tokenizer = AutoTokenizer.from_pretrained("valhalla/distilbart-mnli-12-3")

# %%
# Create a custom pipeline that only requires the text parameter 
# for the __call__ method and provides a method to set the labels
class ZeroShotModelPipeline(ZeroShotClassificationPipeline):
    # Overwrite the __call__ method
    def __call__(self, *args):
        out = super().__call__(args[0], self.set_labels)[0]

        return [[{"label":x[0], "score": x[1]}  for x in zip(out["labels"], out["scores"])]]

    def set_labels(self, labels: Union[str,List[str]]):
        self.set_labels = labels

# %%
text = ["I love playing cricket!"]
labels = ["insect","sports", "animal"]

# %%
# Assign the labels for the classification model
model.config.label2id.update({v:k for k,v in enumerate(labels)})
model.config.id2label.update({k:v for k,v in enumerate(labels)})

# %%
pipe = ZeroShotModelPipeline(model=model, tokenizer=tokenizer, return_all_scores=True)
pipe.set_labels(labels)

# %%
lm_zeroshot_explainer['zero_shot'](pipe, text)
# Out:
# Shap version used: 0.40.0
#   0%|          | 0/42 [00:00<?, ?it/s]
# Partition explainer: 2it [00:24, 24.78s/it]
# Model predictions are: [[{'label': 'sports', 'score': 0.8340923190116882}, {'label': 'insect', 'score': 0.1633770763874054}, {'label': 'animal', 'score': 0.0025305552408099174}]]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_wxzzijnnfexpwjmzfsdr = '_tp_wxzzijnnfexpwjmzfsdr_output_0';
#     document._zoom_wxzzijnnfexpwjmzfsdr = undefined;
#     function _output_onclick_wxzzijnnfexpwjmzfsdr(i) {
#         var next_id = undefined;
#
#         if (document._zoom_wxzzijnnfexpwjmzfsdr !== undefined) {
#             document.getElementById(document._zoom_wxzzijnnfexpwjmzfsdr+ '_zoom').style.display = 'none';
#
#             if (document._zoom_wxzzijnnfexpwjmzfsdr === '_tp_wxzzijnnfexpwjmzfsdr_output_' + i) {
#                 document.getElementById(document._zoom_wxzzijnnfexpwjmzfsdr).style.display = 'block';
#                 document.getElementById(document._zoom_wxzzijnnfexpwjmzfsdr+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_wxzzijnnfexpwjmzfsdr).style.display = 'none';
#                 document.getElementById(document._zoom_wxzzijnnfexpwjmzfsdr+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_wxzzijnnfexpwjmzfsdr !== '_tp_wxzzijnnfexpwjmzfsdr_output_' + i) {
#             next_id = '_tp_wxzzijnnfexpwjmzfsdr_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_wxzzijnnfexpwjmzfsdr = next_id;
#     }
#     function _output_onmouseover_wxzzijnnfexpwjmzfsdr(i, el) {
#         if (document._zoom_wxzzijnnfexpwjmzfsdr !== undefined) { return; }
#         if (document._hover_wxzzijnnfexpwjmzfsdr !== undefined) {
#             document.getElementById(document._hover_wxzzijnnfexpwjmzfsdr + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_wxzzijnnfexpwjmzfsdr).style.display = 'none';
#         }
#         document.getElementById('_tp_wxzzijnnfexpwjmzfsdr_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_wxzzijnnfexpwjmzfsdr = '_tp_wxzzijnnfexpwjmzfsdr_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.1959595959595959); border-radius: 3px; padding: 0px" id="_tp_wxzzijnnfexpwjmzfsdr_output_0_name"
#     onclick="_output_onclick_wxzzijnnfexpwjmzfsdr(0)"
#     onmouseover="_output_onmouseover_wxzzijnnfexpwjmzfsdr(0, this);">insect</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_wxzzijnnfexpwjmzfsdr_output_1_name"
#     onclick="_output_onclick_wxzzijnnfexpwjmzfsdr(1)"
#     onmouseover="_output_onmouseover_wxzzijnnfexpwjmzfsdr(1, this);">sports</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_wxzzijnnfexpwjmzfsdr_output_2_name"
#     onclick="_output_onclick_wxzzijnnfexpwjmzfsdr(2)"
#     onmouseover="_output_onmouseover_wxzzijnnfexpwjmzfsdr(2, this);">animal</div><br><br><div id='_tp_wxzzijnnfexpwjmzfsdr_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="52.423294536031605%" y1="33" x2="52.423294536031605%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="52.423294536031605%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="36.03886963430836%" y1="33" x2="36.03886963430836%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.03886963430836%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="19.65444473258512%" y1="33" x2="19.65444473258512%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="19.65444473258512%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="68.80771943775484%" y1="33" x2="68.80771943775484%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.80771943775484%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="85.19214433947808%" y1="33" x2="85.19214433947808%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="85.19214433947808%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="35.33155295142973%" y1="33" x2="35.33155295142973%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="35.33155295142973%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.191366</text><text x="35.33155295142973%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.191366</text><text x="35.33155295142973%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="33.03864192624784%" y1="33" x2="33.03864192624784%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.03864192624784%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.163377</text><text x="33.03864192624784%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.163377</text><text x="33.03864192624784%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">insect</tspan>(inputs)</text><rect x="23.636871162946%" width="9.40177076330184%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="27.348502335035832%" x2="33.03864192624784%" y1="60" y2="60" id="_fb_mtrzmmcsorrexhxqfzwd_ind_0" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="30.193572130641837%" y="71" font-size="12px" id="_fs_mtrzmmcsorrexhxqfzwd_ind_0" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.069</text><svg x="27.348502335035832%" y="40" height="20" width="5.690139591212009%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle"></text>  </svg></svg><line x1="24.89684848702147%" x2="27.348502335035832%" y1="60" y2="60" id="_fb_mtrzmmcsorrexhxqfzwd_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="26.122675411028652%" y="71" font-size="12px" id="_fs_mtrzmmcsorrexhxqfzwd_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.03</t ...
