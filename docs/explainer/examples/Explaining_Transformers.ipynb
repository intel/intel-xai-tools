# %% [markdown]
# # Explaining transformer models using SHAP
# ## CHAPTER 07 - *Practical exposure of using SHAP in ML*
#
# From **Applied Machine Learning Explainability Techniques** by [**Aditya Bhattacharya**](https://www.linkedin.com/in/aditya-bhattacharya-b59155b6/), published by **Packt**

# %% [markdown]
# ### Objective
#
# The goal of this notebook is to explore model explainability of transformer models trained on text data. Please check out *Chapter 7 - Practical exposure of using SHAP in ML* for other interesting approaches of using SHAP in practice.

# %% [markdown]
# ### Installing the modules

# %% [markdown]
# Install the following libraries in Google Colab or your local environment, if not already installed.

# %%
# !pip install --upgrade numpy shap transformers

# %%
from explainer.explainers import lm_zeroshot_explainer

# %% [markdown]
# ### Loading the modules

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
np.random.seed(123)

import shap
print(f"Shap version used: {shap.__version__}")
import transformers
print(f"Hugging Face transformer version used: {transformers.__version__}")
from transformers import AutoModelForSequenceClassification, AutoTokenizer, ZeroShotClassificationPipeline
from typing import Union, List
# Out:
# Shap version used: 0.41.0
# Hugging Face transformer version used: 4.20.1
# 2022-09-27 00:31:51.816564: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /localdisk/kdkasrav/.conda/envs/xai-tools/lib/libfabric:
# 2022-09-27 00:31:51.816593: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### SHAP and Hugging Face Transformers

# %% [markdown]
# ![SHAP and HF](https://raw.githubusercontent.com/PacktPublishing/Applied-Machine-Learning-Explainability-Techniques/main/Chapter07/images/Shap_HF.jpg)

# %% [markdown]
# In this tutorial we will apply SHAP for explaining Hugging Face transformer models trained on text data. Hugging Face Transformers (https://github.com/huggingface/transformers) are state of the art pre-trained transformer models trained on huge amount of data. This framework provides you the option of utilizing pre-trained models on various applications using just few lines of code. The pre-trained models can be easily downloaded and fine-tuned on any custom dataset and can be integrated very easily with other applications.

# %% [markdown]
# Now, let's try the hugging face transformer models for text sentiment analysis.

# %% [markdown]
# ### Explaining transformer based Sentiment Analysis models

# %%
# Loading the transformers pipeline model for Sentiment analysis
model = transformers.pipeline('sentiment-analysis', return_all_scores=True)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# 2022-09-27 00:26:05.473546: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /localdisk/kdkasrav/.conda/envs/xai-tools/lib/libfabric:
# 2022-09-27 00:26:05.474098: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-27 00:26:05.474139: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (xai-kdkasrav): /proc/driver/nvidia/version does not exist
# 2022-09-27 00:26:05.476707: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %%
# Loading the text data
text_data = "Hugging face transformers are absolutely brilliant!"

# %%
model(text_data)[0]
# Out:
# {'label': 'NEGATIVE', 'score': 0.00013269631017465144}

# %% [markdown]
# So, we can see that the model predicted the outcome to be positive with a very high confidence score, which is correct! Now, let's see if this can be explained using SHAP.

# %%
# Defining SHAP explainer object
explainer = shap.Explainer(model) 
shap_values = explainer([text_data])

# %%
shap.plots.text(shap_values[0,:,'POSITIVE'])
# Out:
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="46.5113418751059%" y1="33" x2="46.5113418751059%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="46.5113418751059%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="28.224097215559052%" y1="33" x2="28.224097215559052%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="28.224097215559052%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="9.936852556012193%" y1="33" x2="9.936852556012193%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="9.936852556012193%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="64.79858653465276%" y1="33" x2="64.79858653465276%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="64.79858653465276%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="83.08583119419961%" y1="33" x2="83.08583119419961%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.08583119419961%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="16.926299643992362%" y1="33" x2="16.926299643992362%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.926299643992362%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.276441</text><text x="16.926299643992362%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.276441</text><text x="16.926299643992362%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="83.07369944164539%" y1="33" x2="83.07369944164539%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.07369944164539%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999867</text><text x="83.07369944164539%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.999867</text><text x="83.07369944164539%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">POSITIVE</tspan>(inputs)</text><rect x="8.333333257136479%" width="74.74036618450891%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="46.10711921028094%" x2="83.07369944164539%" y1="60" y2="60" id="_fb_rfmwfpslnrzmyuszfamo_ind_1" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="64.59040932596317%" y="71" font-size="12px" id="_fs_rfmwfpslnrzmyuszfamo_ind_1" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.404</text><svg x="46.10711921028094%" y="40" height="20" width="36.966580231364446%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">Hugging</text>  </svg></svg><line x1="26.92074437074133%" x2="46.10711921028094%" y1="60" y2="60" id="_fb_rfmwfpslnrzmyuszfamo_ind_5" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="36.51393179051114%" y="71" font-size="12px" id="_fs_rfmwfpslnrzmyuszfamo_ind_5" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.21</text><svg x="26.92074437074133%" y="40" height="20" width="19.186374839539614%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9 ...

# %%
shap.plots.bar(shap_values[0,:,'POSITIVE'])

# %% [markdown]
# As we can clearly see, using the force plot and bar plots in SHAP, we can visualize the words which contributes positively and the words which contribute negatively towards the model prediction. Now, let's try out with a multi-class classification example using the Hugging Face transformers.

# %% [markdown]
# ### Explaining Multi-Class prediction transformer models using SHAP

# %%
# Loading the hugging face model and tokenizer
tokenizer = transformers.AutoTokenizer.from_pretrained("nateraw/bert-base-uncased-emotion", use_fast=True)
model = transformers.AutoModelForSequenceClassification.from_pretrained("nateraw/bert-base-uncased-emotion")

# build a pipeline object to do predictions
pipeline = transformers.pipeline("text-classification", model=model, tokenizer=tokenizer, device=0, return_all_scores=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [3], line 6
#       3 model = transformers.AutoModelForSequenceClassification.from_pretrained("nateraw/bert-base-uncased-emotion")
#       5 # build a pipeline object to do predictions
# ----> 6 pipeline = transformers.pipeline("text-classification", model=model, tokenizer=tokenizer, device=0, return_all_scores=True)
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/transformers/pipelines/__init__.py:684, in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, model_kwargs, pipeline_class, **kwargs)
#     681 if feature_extractor is not None:
#     682     kwargs["feature_extractor"] = feature_extractor
# --> 684 return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/transformers/pipelines/text_classification.py:68, in TextClassificationPipeline.__init__(self, **kwargs)
#      67 def __init__(self, **kwargs):
# ---> 68     super().__init__(**kwargs)
#      70     self.check_model_type(
#      71         TF_MODEL_FOR_SEQUENCE_CLASSIFICATION_MAPPING
#      72         if self.framework == "tf"
#      73         else MODEL_FOR_SEQUENCE_CLASSIFICATION_MAPPING
#      74     )
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/transformers/pipelines/base.py:770, in Pipeline.__init__(self, model, tokenizer, feature_extractor, modelcard, framework, task, args_parser, device, binary_output, **kwargs)
#     768 # Special handling
#     769 if self.framework == "pt" and self.device.type == "cuda":
# --> 770     self.model = self.model.to(self.device)
#     772 # Update config with task specific parameters
#     773 task_specific_params = self.model.config.task_specific_params
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/torch/nn/modules/module.py:927, in Module.to(self, *args, **kwargs)
#     923         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     924                     non_blocking, memory_format=convert_to_format)
#     925     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# --> 927 return self._apply(convert)
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/torch/nn/modules/module.py:579, in Module._apply(self, fn)
#     577 def _apply(self, fn):
#     578     for module in self.children():
# --> 579         module._apply(fn)
#     581     def compute_should_use_set_data(tensor, tensor_applied):
#     582         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     583             # If the new tensor has compatible tensor type as the existing tensor,
#     584             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     589             # global flag to let the user control whether they want the future
#     590             # behavior of overwriting the existing tensor or not.
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/torch/nn/modules/module.py:579, in Module._apply(self, fn)
#     577 def _apply(self, fn):
#     578     for module in self.children():
# --> 579         module._apply(fn)
#     581     def compute_should_use_set_data(tensor, tensor_applied):
#     582         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     583             # If the new tensor has compatible tensor type as the existing tensor,
#     584             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     589             # global flag to let the user control whether they want the future
#     590             # behavior of overwriting the existing tensor or not.
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/torch/nn/modules/module.py:579, in Module._apply(self, fn)
#     577 def _apply(self, fn):
#     578     for module in self.children():
# --> 579         module._apply(fn)
#     581     def compute_should_use_set_data(tensor, tensor_applied):
#     582         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     583             # If the new tensor has compatible tensor type as the existing tensor,
#     584             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     589             # global flag to let the user control whether they want the future
#     590             # behavior of overwriting the existing tensor or not.
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/torch/nn/modules/module.py:602, in Module._apply(self, fn)
#     598 # Tensors stored in modules are graph leaves, and we don't want to
#     599 # track autograd history of `param_applied`, so we have to use
#     600 # `with torch.no_grad():`
#     601 with torch.no_grad():
# --> 602     param_applied = fn(param)
#     603 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     604 if should_use_set_data:
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/torch/nn/modules/module.py:925, in Module.to.<locals>.convert(t)
#     922 if convert_to_format is not None and t.dim() in (4, 5):
#     923     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     924                 non_blocking, memory_format=convert_to_format)
# --> 925 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# File ~/Github/intel-innersource/frameworks.ai.explainable-ai/explainer/explainer/explainers/lm_zeroshot_explainer/torch/cuda/__init__.py:217, in _lazy_init()
#     213     raise AssertionError(
#     214         "libcudart functions unavailable. It looks like you have a broken build?")
#     215 # This function throws if there's a driver initialization error, no GPUs
#     216 # are found or any other error occurs
# --> 217 torch._C._cuda_init()
#     218 # Some of the queued calls may reentrantly call _lazy_init();
#     219 # we need to just return without initializing in that case.
#     220 # However, we must not let any *other* threads in!
#     221 _tls.is_initializing = True
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
# explaining using SHAP
explainer = shap.Explainer(pipeline)
shap_values = explainer([text_data])
shap.plots.text(shap_values[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 2
#       1 # explaining using SHAP
# ----> 2 explainer = shap.Explainer(pipeline)
#       3 shap_values = explainer([text_data])
#       4 shap.plots.text(shap_values[0])
#
# NameError: name 'pipeline' is not defined

# %%
# Let's visualize the feature importance towards the outcome - joy
shap.plots.bar(shap_values[0,:,'joy'])

# %%
# Let's visualize the feature importance towards the outcome - sadness
shap.plots.bar(shap_values[0,:,'sadness'])

# %% [markdown]
# Now, we have applied SHAP to explain a pre-trained multi-class classification model from Hugging Face. The pre-trained model is used to detect the emotions - *sadness, joy, love, anger, fear, surprise* from text data. Using SHAP's force plot and bar plots, we can visualize the influence of each word present in the sentence towards the model's prediction. For the selected example - "*Hugging face transformers are absolutely brilliant!*", the words *brilliant* and *absolutely* contribute the most towards model's prediction as *joy*.

# %% [markdown]
# For the outcome *sadness*, we can see that almost all the words contribute negatively and this signifies that the outcome can never be *sadness*

# %% [markdown]
# Next, let us try out another very interesting concept used in NLP - Zero-Shot Learning. Zero-Shot Learning enables us to apply a trained model without fine-tuning on any labelled sample. Check out this: https://discuss.huggingface.co/t/new-pipeline-for-zero-shot-text-classification/681 to find out more on using Zero-Shot learning using hugging face transformers.

# %% [markdown]
# ### Explaining Zero-Shot Learning using SHAP

# %%
# Loading the hugging face model and tokenizer
model = AutoModelForSequenceClassification.from_pretrained("valhalla/distilbart-mnli-12-3")
tokenizer = AutoTokenizer.from_pretrained("valhalla/distilbart-mnli-12-3")
# Out:
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/977M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
# Create a custom pipeline that only requires the text parameter 
# for the __call__ method and provides a method to set the labels
class ZeroShotModelPipeline(ZeroShotClassificationPipeline):
    # Overwrite the __call__ method
    def __call__(self, *args):
        out = super().__call__(args[0], self.set_labels)[0]

        return [[{"label":x[0], "score": x[1]}  for x in zip(out["labels"], out["scores"])]]

    def set_labels(self, labels: Union[str,List[str]]):
        self.set_labels = labels

# %%
def score_and_visualize(text, shap_values):
    prediction = pipe(text)
    print(f"Model predictions are: {prediction}")
    shap.plots.text(shap_values)

# %%
text = ["I love playing cricket!"]
labels = ["insect","sports", "animal"]

# %%
# Assign the labels for the classification model
model.config.label2id.update({v:k for k,v in enumerate(labels)})
model.config.id2label.update({k:v for k,v in enumerate(labels)})

# %%
pipe = ZeroShotModelPipeline(model=model, tokenizer=tokenizer, return_all_scores=True)
pipe.set_labels(labels)

# %%
# SHAP Explainer
explainer = shap.Explainer(pipe)
shap_values = explainer(text)
# Out:
# 2022-09-27 00:33:31.473677: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /localdisk/kdkasrav/.conda/envs/xai-tools/lib/libfabric:
# 2022-09-27 00:33:31.473707: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-27 00:33:31.473727: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (xai-kdkasrav): /proc/driver/nvidia/version does not exist
# 2022-09-27 00:33:31.474193: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#   0%|          | 0/42 [00:00<?, ?it/s]
# Partition explainer: 2it [00:10, 10.44s/it]

# %%
score_and_visualize(text, shap_values)
# Out:
# Model predictions are: [[{'label': 'sports', 'score': 0.8340911865234375}, {'label': 'insect', 'score': 0.1633782833814621}, {'label': 'animal', 'score': 0.0025305503513664007}]]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_lqfpfwyocihdbsggrcyn = '_tp_lqfpfwyocihdbsggrcyn_output_0';
#     document._zoom_lqfpfwyocihdbsggrcyn = undefined;
#     function _output_onclick_lqfpfwyocihdbsggrcyn(i) {
#         var next_id = undefined;
#
#         if (document._zoom_lqfpfwyocihdbsggrcyn !== undefined) {
#             document.getElementById(document._zoom_lqfpfwyocihdbsggrcyn+ '_zoom').style.display = 'none';
#
#             if (document._zoom_lqfpfwyocihdbsggrcyn === '_tp_lqfpfwyocihdbsggrcyn_output_' + i) {
#                 document.getElementById(document._zoom_lqfpfwyocihdbsggrcyn).style.display = 'block';
#                 document.getElementById(document._zoom_lqfpfwyocihdbsggrcyn+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_lqfpfwyocihdbsggrcyn).style.display = 'none';
#                 document.getElementById(document._zoom_lqfpfwyocihdbsggrcyn+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_lqfpfwyocihdbsggrcyn !== '_tp_lqfpfwyocihdbsggrcyn_output_' + i) {
#             next_id = '_tp_lqfpfwyocihdbsggrcyn_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_lqfpfwyocihdbsggrcyn = next_id;
#     }
#     function _output_onmouseover_lqfpfwyocihdbsggrcyn(i, el) {
#         if (document._zoom_lqfpfwyocihdbsggrcyn !== undefined) { return; }
#         if (document._hover_lqfpfwyocihdbsggrcyn !== undefined) {
#             document.getElementById(document._hover_lqfpfwyocihdbsggrcyn + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_lqfpfwyocihdbsggrcyn).style.display = 'none';
#         }
#         document.getElementById('_tp_lqfpfwyocihdbsggrcyn_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_lqfpfwyocihdbsggrcyn = '_tp_lqfpfwyocihdbsggrcyn_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.1959595959595959); border-radius: 3px; padding: 0px" id="_tp_lqfpfwyocihdbsggrcyn_output_0_name"
#     onclick="_output_onclick_lqfpfwyocihdbsggrcyn(0)"
#     onmouseover="_output_onmouseover_lqfpfwyocihdbsggrcyn(0, this);">insect</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_lqfpfwyocihdbsggrcyn_output_1_name"
#     onclick="_output_onclick_lqfpfwyocihdbsggrcyn(1)"
#     onmouseover="_output_onmouseover_lqfpfwyocihdbsggrcyn(1, this);">sports</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_lqfpfwyocihdbsggrcyn_output_2_name"
#     onclick="_output_onclick_lqfpfwyocihdbsggrcyn(2)"
#     onmouseover="_output_onmouseover_lqfpfwyocihdbsggrcyn(2, this);">animal</div><br><br><div id='_tp_lqfpfwyocihdbsggrcyn_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.63862043794613%" y1="33" x2="51.63862043794613%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.63862043794613%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="34.98392758322123%" y1="33" x2="34.98392758322123%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.98392758322123%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="18.329234728496328%" y1="33" x2="18.329234728496328%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.329234728496328%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="68.29331329267104%" y1="33" x2="68.29331329267104%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.29331329267104%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="84.94800614739593%" y1="33" x2="84.94800614739593%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="84.94800614739593%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="34.264944656199816%" y1="33" x2="34.264944656199816%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.264944656199816%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.191366</text><text x="34.264944656199816%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.191366</text><text x="34.264944656199816%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="31.934310372748612%" y1="33" x2="31.934310372748612%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="31.934310372748612%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.163378</text><text x="31.934310372748612%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.163378</text><text x="31.934310372748612%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">insect</tspan>(inputs)</text><rect x="22.393558425256078%" width="9.540751947492533%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="26.150304387726635%" x2="31.934310372748612%" y1="60" y2="60" id="_fb_uaqqousokmhoazfbasly_ind_0" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="29.042307380237624%" y="71" font-size="12px" id="_fs_uaqqousokmhoazfbasly_ind_0" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.069</text><svg x="26.150304387726635%" y="40" height="20" width="5.784005985021977%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle"></text>  </svg></svg><line x1="23.674325923847384%" x2="26.150304387726635%" y1="60" y2="60" id="_fb_uaqqousokmhoazfbasly_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="24.91231515578701%" y="71" font-size="12px" id="_fs_uaqqousokmhoazfbasly_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor=" ...

# %%
# Let's visualize the feature importance towards the outcome - sports
shap.plots.bar(shap_values[0,:,'sports'])

# %% [markdown]
# Hugging Face transformer framework, allows us to apply Zero-Shot learning in just few lines of code using pre-trained models without re-training or fine tuning on any labeled sample. Now, we have applied this model on a slightly difficult example. The example used is "I love playing cricket!". *Cricket* can be a sport or even it can an insect. So, ideally, the word cricket individually can contribute towards both the categories. But the term '*playing cricket*' definitely indicates the category sports.

# %% [markdown]
# Although the model correctly predicted the category as sports, but when we used SHAP, we found out that the word *Cricket* has a negative contribution towards the model prediction. These are situations where model explainability is extremely crucial. Ideally speaking, the most important word that should contribute towards the correct prediction of the class sports, should have been *Cricket* and not *love*. This tells us that model is not robust enough and does have scope of improvement especially for the classes used for prediction.

# %% [markdown]
# ## Final Thoughts

# %% [markdown]
# Transformers are indeed state of the model, especially for text data. Pre-trained transformer does make it easy to productionalize any intelligent system, without the hassle of training the algorithm from scratch. But explaining complicated models like Transformers can be really hard! In this tutorial, we have seen how easily SHAP can be used to explain transformer models from Hugging Face!

# %% [markdown]
# ## Reference

# %% [markdown]
# 1. Transformer Model - https://en.wikipedia.org/wiki/Transformer_(machine_learning_model)
# 2. SHAP GitHub Project - https://github.com/slundberg/shap
# 3. SHAP Documentations - https://shap.readthedocs.io/en/latest/index.html
# 4. Hugging Face Transformer - https://github.com/huggingface/transformers
# 5. Hugging Face Zero-Shot Learning - https://discuss.huggingface.co/t/new-pipeline-for-zero-shot-text-classification/681
# 6. Zero-Shot Learning - https://towardsdatascience.com/zero-and-few-shot-learning-c08e145dc4ed
# 7. Some of the utility functions and code are taken from the GitHub Repository of the author - Aditya Bhattacharya https://github.com/adib0073
