# %%
# %conda install python-graphviz
# %conda install pydot
# %conda install pygraphviz
# %pip install pybaobabdt
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::arrow==1.2.1=pyhd8ed1ab_0
#   - conda-forge/noarch::black==21.12b0=pyhd8ed1ab_0
#   - conda-forge/noarch::cookiecutter==1.7.3=pyh6c4a22f_0
#   - conda-forge/noarch::gitpython==3.1.26=pyhd8ed1ab_0
#   - conda-forge/noarch::ipympl==0.8.6=pyhd8ed1ab_0
#   - conda-forge/noarch::ipywidgets==7.6.5=pyhd8ed1ab_0
#   - conda-forge/noarch::jinja2-time==0.2.0=py_2
#   - conda-forge/noarch::jupyter-lsp==1.5.1=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter-lsp-python==1.5.1=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter-server-mathjax==0.2.3=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_server==1.13.3=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab==3.2.8=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab-git==0.34.2=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab-lsp==3.10.0=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab_server==2.10.3=pyhd8ed1ab_0
#   - conda-forge/linux-64::matplotlib==3.5.1=py38h578d9bd_0
#   - conda-forge/noarch::nbclassic==0.3.5=pyhd8ed1ab_0
#   - conda-forge/noarch::nbclient==0.5.10=pyhd8ed1ab_1
#   - conda-forge/linux-64::nbconvert==6.4.0=py38h578d9bd_0
#   - conda-forge/noarch::nbdime==3.1.1=pyhd8ed1ab_0
#   - conda-forge/noarch::nbformat==5.1.3=pyhd8ed1ab_0
#   - conda-forge/noarch::notebook==6.4.7=pyha770c72_0
#   - conda-forge/linux-64::pandas==1.3.5=py38h43a58ef_0
#   - conda-forge/noarch::patsy==0.5.2=pyhd8ed1ab_0
#   - defaults/noarch::python-lsp-server==1.2.4=pyhd3eb1b0_0
#   - conda-forge/linux-64::scipy==1.7.3=py38h56a6a73_0
#   - conda-forge/linux-64::statsmodels==0.13.1=py38h6c62de6_0
#   - conda-forge/linux-64::widgetsnbextension==3.5.2=py38h578d9bd_1
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/kdkasrav/.conda/envs/interpret
#
#   added / updated specs:
#     - python-graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.3.29  |       h06a4308_1         122 KB  defaults
#     certifi-2021.10.8          |   py38h06a4308_2         152 KB  defaults
#     click-8.0.4                |   py38h06a4308_0         151 KB  defaults
#     ipykernel-6.9.1            |   py38h06a4308_0         199 KB  defaults
#     ipython-8.2.0              |   py38h06a4308_0         993 KB  defaults
#     jinja2-2.11.3              |     pyhd8ed1ab_1          94 KB  conda-forge
#     jsonschema-4.4.0           |   py38h06a4308_0         121 KB  defaults
#     numpy-1.22.3               |   py38h1d589f8_2         6.8 MB  conda-forge
#     openssl-1.1.1n             |       h7f8727e_0         2.5 MB  defaults
#     python-graphviz-0.16       |     pyhd3eb1b0_1          20 KB  defaults
#     typing_extensions-4.1.1    |     pyh06a4308_0          28 KB  defaults
#     ------------------------------------------------------------
#                                            Total:        11.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   autopep8           conda-forge/noarch::autopep8-1.5.7-pyhd8ed1ab_0
#   click              pkgs/main/linux-64::click-8.0.4-py38h06a4308_0
#   ipykernel          pkgs/main/linux-64::ipykernel-6.9.1-py38h06a4308_0
#   ipython            pkgs/main/linux-64::ipython-8.2.0-py38h06a4308_0
#   jinja2             conda-forge/noarch::jinja2-2.11.3-pyhd8ed1ab_1
#   jsonschema         pkgs/main/linux-64::jsonschema-4.4.0-py38h06a4308_0
#   markupsafe         pkgs/main/linux-64::markupsafe-1.1.1-py38h7b6447c_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.5.1-py38hf4fb855_0
#   numpy              conda-forge/linux-64::numpy-1.22.3-py38h1d589f8_2
#   typing_extensions  pkgs/main/noarch::typing_extensions-4.1.1-pyh06a4308_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2021.10.~ --> pkgs/main::ca-certificates-2022.3.29-h06a4308_1
#   certifi            conda-forge::certifi-2021.10.8-py38h5~ --> pkgs/main::certifi-2021.10.8-py38h06a4308_2
#   openssl            conda-forge::openssl-1.1.1l-h7f98852_0 --> pkgs/main::openssl-1.1.1n-h7f8727e_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   python-graphviz    conda-forge::python-graphviz-0.19.1-p~ --> pkgs/main::python-graphviz-0.16-pyhd3eb1b0_1
#
#
#
# Downloading and Extracting Packages
# numpy-1.22.3         | 6.8 MB    | ##################################### | 100%
# typing_extensions-4. | 28 KB     | ##################################### | 100%
# ca-certificates-2022 | 122 KB    | ##################################### | 100%
# jinja2-2.11.3        | 94 KB     | ##################################### | 100%
# click-8.0.4          | 151 KB    | ##################################### | 100%
# python-graphviz-0.16 | 20 KB     | ##################################### | 100%
# openssl-1.1.1n       | 2.5 MB    | ##################################### | 100%
# ipython-8.2.0        | 993 KB    | ##################################### | 100%
# certifi-2021.10.8    | 152 KB    | ##################################### | 100%
# ipykernel-6.9.1      | 199 KB    | ##################################### | 100%
# jsonschema-4.4.0     | 121 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/kdkasrav/.conda/envs/interpret
#
#   added / updated specs:
#     - pydot
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pydot-1.4.1                |   py38h06a4308_0          43 KB  defaults
#     ------------------------------------------------------------
#                                            Total:          43 KB
#
# The following NEW packages will be INSTALLED:
#
#   pydot              pkgs/main/linux-64::pydot-1.4.1-py38h06a4308_0
#
#
#
# Downloading and Extracting Packages
# pydot-1.4.1          | 43 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/kdkasrav/.conda/envs/interpret
#
#   added / updated specs:
#     - pygraphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pygraphviz-1.9             |   py38h86b1bdd_0         127 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         127 KB
#
# The following NEW packages will be INSTALLED:
#
#   pygraphviz         conda-forge/linux-64::pygraphviz-1.9-py38h86b1bdd_0
#
#
#
# Downloading and Extracting Packages
# pygraphviz-1.9       | 127 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pybaobabdt in /Users/kdkasrav/.conda/envs/interpret/lib/python3.8/site-packages (1.0.1)

# %%
import pandas as pd
import pybaobabdt
from scipy.io import arff
from sklearn.tree import DecisionTreeClassifier

# %%
data = arff.loadarff("../data/winequality-red.arff")
df = pd.DataFrame(data[0])

y = list(df["class"])
features = list(df.columns)
features.remove("class")
X = df.loc[:, features]

clf = DecisionTreeClassifier().fit(X, y)
ax = pybaobabdt.drawTree(clf, size=10, dpi=72, features=features)
